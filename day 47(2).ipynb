# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x='tip',y='total_bill',data=df)

# %%
sns.relplot(x='tip',y='total_bill',data=df,hue='sex')

# %%
sns.relplot(x='tip',y='total_bill',data=df,hue='smoker')

# %%
sns.relplot(x='tip',y='total_bill',data=df,hue='sex',style='smoker')

# %%
sns.relplot(x='tip',y='total_bill',data=df,hue='smoker',style='smoker',size='time')

# %%
sns.relplot(x='tip',y='total_bill',data=df,hue='smoker',style='smoker',size='size')

# %%
sns.countplot(x=df['smoker'])
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.countplot(x=df['sex'])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x=df['size'])
# Out:
# <Axes: xlabel='size', ylabel='count'>

# %%
sns.countplot(x=df['time'])
# Out:
# <Axes: xlabel='time', ylabel='count'>

# %%
df['smoker'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='smoker'>

# %%
sns.boxplot(x=df['tip'])
# Out:
# <Axes: xlabel='tip'>

# %%
sns.boxplot(x=df['total_bill'])
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.distplot(x=df['total_bill'])
# Out:
# C:\Users\bansa\AppData\Local\Temp\ipykernel_12528\1985914644.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df['total_bill'])
# <Axes: ylabel='Density'>

# %%
sns.distplot(x=df['total_bill'],kde=False)
# Out:
# C:\Users\bansa\AppData\Local\Temp\ipykernel_12528\1332747252.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df['total_bill'],kde=False)
# <Axes: >

# %%
sns.distplot(x=df['total_bill'],hist=False)
# Out:
# C:\Users\bansa\AppData\Local\Temp\ipykernel_12528\2669819339.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df['total_bill'],hist=False)
# <Axes: ylabel='Density'>

# %%
sns.displot(x=df['total_bill'])
