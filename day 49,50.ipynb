# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %%
data=pd.read_csv('insurance_claims.csv')

# %%
data.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... witnesses police_report_available total_claim_amount  \
# ...

# %%
data.shape
# Out:
# (1000, 39)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 39 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %%
data['fraud_reported'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='fraud_reported'>

# %%
data.describe()
# Out:
#        months_as_customer          age  policy_number  policy_deductable  \
# count         1000.000000  1000.000000    1000.000000        1000.000000
# mean           203.954000    38.948000  546238.648000        1136.000000
# std            115.113174     9.140287  257063.005276         611.864673
# min              0.000000    19.000000  100804.000000         500.000000
# 25%            115.750000    32.000000  335980.250000         500.000000
# 50%            199.500000    38.000000  533135.000000        1000.000000
# 75%            276.250000    44.000000  759099.750000        2000.000000
# max            479.000000    64.000000  999435.000000        2000.000000
#
#        policy_annual_premium  umbrella_limit    insured_zip  capital-gains  \
# count            1000.000000    1.000000e+03    1000.000000    1000.000000
# mean             1256.406150    1.101000e+06  501214.488000   25126.100000
# std               244.167395    2.297407e+06   71701.610941   27872.187708
# ...

# %%
fraud_count=data['fraud_reported'].value_counts().reset_index().rename(columns={'count':'Count'})

# %%
fraud_count
# Out:
#   fraud_reported  Count
# 0              N    753
# 1              Y    247

# %%
#fraud_count.to_csv('abhi.csv')

# %%
sns.barplot(x='fraud_reported',y='Count',data=fraud_count,palette="husl")
# Out:
# C:\Users\bansa\AppData\Local\Temp\ipykernel_1836\1963840406.py:1: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# <Axes: xlabel='fraud_reported', ylabel='Count'>

# %%
px.bar(x=fraud_count['fraud_reported'],y=fraud_count['Count'],text=fraud_count['Count'])

# %%
px.histogram(data,x='fraud_reported',color='fraud_reported',title='Fraud_reported')

# %%
data['fraud_reported'].value_counts().index
# Out:
# Index(['N', 'Y'], dtype='object', name='fraud_reported')

# %%
plt.pie(labels=data['fraud_reported'].value_counts().index,x=data['fraud_reported'].value_counts().values,autopct='%1.1f%%')
plt.show()

# %%
px.pie (names=['NO FRAUD REPORTED','FRAUD REPORTED'],values=data.fraud_reported.value_counts().values,title='Fraud Reported',width=700,height=700)

# %%
data['incident_type'].value_counts()
# Out:
# incident_type
# Multi-vehicle Collision     419
# Single Vehicle Collision    403
# Vehicle Theft                94
# Parked Car                   84
# Name: count, dtype: int64

# %%
incident_count=data['incident_type'].value_counts().reset_index().rename(columns={'count':'Count'})

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='incident_type',y='Count',data=fraud_count,palette="husl")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[82], line 2
#       1 plt.figure(figsize=(12,6))
# ----> 2 sns.barplot(x='incident_type',y='Count',data=fraud_count,palette="husl")
#       3 plt.show()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2341, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2338 if estimator is len:
#    2339     estimator = "size"
# -> 2341 p = _CategoricalAggPlotter(
#    2342     data=data,
#    2343     variables=dict(x=x, y=y, hue=hue, units=units, weight=weights),
#    2344     order=order,
#    2345     orient=orient,
#    2346     color=color,
#    2347     legend=legend,
#    2348 )
# ...

# %%
sns.barplot(x='incident_type',y='Count',data=fraud_count,palette="husl")
plt.xticks(rotation=75)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 sns.barplot(x='incident_type',y='Count',data=fraud_count,palette="husl")
#       2 plt.xticks(rotation=75)
#       3 plt.show()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2341, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2338 if estimator is len:
#    2339     estimator = "size"
# -> 2341 p = _CategoricalAggPlotter(
#    2342     data=data,
#    2343     variables=dict(x=x, y=y, hue=hue, units=units, weight=weights),
#    2344     order=order,
#    2345     orient=orient,
#    2346     color=color,
#    2347     legend=legend,
#    2348 )
# ...

# %%
px.bar(x=incident_count['incident_type'],y=fraud_count['Count'],text=incident_count['Count'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 px.bar(x=incident_count['incident_type'],y=fraud_count['Count'],text=incident_count['Count'])
#
# File ~\anaconda3\Lib\site-packages\plotly\express\_chart_types.py:373, in bar(data_frame, x, y, color, pattern_shape, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, custom_data, text, base, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, pattern_shape_sequence, pattern_shape_map, range_color, color_continuous_midpoint, opacity, orientation, barmode, log_x, log_y, range_x, range_y, text_auto, title, template, width, height)
#     325 def bar(
#     326     data_frame=None,
#     327     x=None,
#    (...)
# ...

# %%
px.histogram(data,x='incident_type',color='incident_type',title='Incident_Type')

# %%
data.groupby('incident_type')['fraud_reported'].value_counts()
# Out:
# incident_type             fraud_reported
# Multi-vehicle Collision   N                 305
#                           Y                 114
# Parked Car                N                  76
#                           Y                   8
# Single Vehicle Collision  N                 286
#                           Y                 117
# Vehicle Theft             N                  86
#                           Y                   8
# Name: count, dtype: int64

# %%
plt.pie(labels=data['incident_type'].value_counts().index,x=data['incident_type'].value_counts().values,autopct='%1.1f%%')
plt.show()

# %%
px.pie (values=data.incident_type.value_counts().values,title='Incident Type',width=500,height=500)

# %%
data['insured_sex'].value_counts()
# Out:
# insured_sex
# FEMALE    537
# MALE      463
# Name: count, dtype: int64

# %%
insured_sex_count=data['insured_sex'].value_counts().reset_index().rename(columns={'count':'Count'})

# %%
insured_sex_count
# Out:
#   insured_sex  Count
# 0      FEMALE    537
# 1        MALE    463

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='insured_sex',y='Count',data=insured_sex_count,palette="husl")
plt.show()
# Out:
# C:\Users\bansa\AppData\Local\Temp\ipykernel_1836\910450273.py:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
px.bar(x=insured_sex_count['insured_sex'],y=insured_sex_count['Count'],text=insured_sex_count['Count'])

# %%
px.histogram(data,x='insured_sex',color='insured_sex',title='Insured_sex')

# %%
data['insured_education_level'].value_counts()
# Out:
# insured_education_level
# JD             161
# High School    160
# Associate      145
# MD             144
# Masters        143
# PhD            125
# College        122
# Name: count, dtype: int64

# %%
education_level=data['insured_education_level'].value_counts().reset_index().rename(columns={'count':'Count'})

# %%
px.bar(x=education_level['insured_education_level'],y=education_level['Count'],text=education_level['Count'])

# %%
px.histogram(data,x='insured_education_level',color='insured_education_level',title='Insured_education')

# %%
df=data.select_dtypes(exclude=[object])
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip',
#        'capital-gains', 'capital-loss', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'bodily_injuries', 'witnesses',
#        'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim',
#        'auto_year'],
#       dtype='object')

# %%
sns.distplot(df['age'])
# Out:
# C:\Users\bansa\AppData\Local\Temp\ipykernel_1836\3234920688.py:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.displot(df['age'],kde=True)

# %%
plt.hist(df['age'],bins=20)
# Out:
# (array([  8.,   8.,  24.,  50., 107.,  80.,  83.,  64., 131.,  83.,  81.,
#          58.,  82.,  27.,  13.,  23.,  38.,  13.,  19.,   8.]),
#  array([19.  , 21.25, 23.5 , 25.75, 28.  , 30.25, 32.5 , 34.75, 37.  ,
#         39.25, 41.5 , 43.75, 46.  , 48.25, 50.5 , 52.75, 55.  , 57.25,
#         59.5 , 61.75, 64.  ]),
#  <BarContainer object of 20 artists>)

# %%
sns.boxplot(df['age'])
# Out:
# <Axes: ylabel='age'>

# %%
df['age'].max()
# Out:
# 64

# %%
df[df['age']==64]
# Out:
#      months_as_customer  age  policy_number  policy_deductable  \
# 67                  478   64         346002                500
# 588                 472   64         911429                500
#
#      policy_annual_premium  umbrella_limit  insured_zip  capital-gains  \
# 67                  835.02               0       602433          59600
# 588                 989.24               0       615821              0
#
#      capital-loss  incident_hour_of_the_day  number_of_vehicles_involved  \
# 67              0                        17                            3
# 588             0                        13                            1
#
#      bodily_injuries  witnesses  total_claim_amount  injury_claim  \
# 67                 1          1               33930             0
# 588                2          3               70900         14180
#
#      property_claim  vehicle_claim  auto_year
# 67             3770          30160       1998
# ...

# %%
df.drop([67,588],inplace=True)

# %%
sns.boxplot(df['age'])
# Out:
# <Axes: ylabel='age'>

# %%
px.box(df,y='age')

# %%
px.box(df,y='age',notched=True)

# %%
sns.distplot(df['insured_zip'])
# Out:
# C:\Users\bansa\AppData\Local\Temp\ipykernel_1836\1191715835.py:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# <Axes: xlabel='insured_zip', ylabel='Density'>

# %%
sns.displot(y=df['insured_zip'])

# %%
plt.hist(df['insured_zip'])
# Out:
# (array([261., 264., 181.,   0.,   0.,   0.,   0.,   0.,  28., 264.]),
#  array([430104. , 449189.8, 468275.6, 487361.4, 506447.2, 525533. ,
#         544618.8, 563704.6, 582790.4, 601876.2, 620962. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.boxplot(df['insured_zip'])
# Out:
# <Axes: ylabel='insured_zip'>

# %%
sns.displot(df['capital-loss'])

# %%
plt.hist(df['capital-loss'])
# Out:
# (array([  1.,   7.,  20.,  60., 111., 146.,  99.,  59.,  18., 477.]),
#  array([-111100.,  -99990.,  -88880.,  -77770.,  -66660.,  -55550.,
#          -44440.,  -33330.,  -22220.,  -11110.,       0.]),
#  <BarContainer object of 10 artists>)

# %%
sns.boxplot(df['capital-loss'])
# Out:
# <Axes: ylabel='capital-loss'>
